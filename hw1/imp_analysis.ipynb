# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
imp1 = np.load("imp1.npy")
imp2 = np.load("imp2.npy")

# %%
# Assuming imp1 is a numpy array or list of importance scores
x = np.array(range(len(imp1)))

# Sort indices by descending importance
imp1_ix = np.argsort(imp1)[::-1]

# Create the bar plot with sorted importance
plt.bar(x, imp1[imp1_ix])

# Set x-ticks to the indices of the sorted bars
plt.show()
x[imp1_ix]
# Out:
# array([ 65, 319, 384, 279, 294, 330, 359, 233,  43, 301, 152, 190, 311,
#        375, 243,  30, 305, 366, 362, 269, 357, 354,  79,  61,  91, 105,
#        327, 221,  59, 155, 293, 193, 273,  62, 355, 266, 159,   6, 156,
#        387, 361, 184,  75, 386, 347, 314,  58,  86, 232, 163, 262,  21,
#         22,   0, 275, 214,  51, 296,  35, 168, 148,  88,  53, 376, 123,
#        189, 234, 350, 283, 295,  92, 333, 222, 308, 349,  13, 224, 225,
#        138, 282, 377, 126, 235, 316, 210, 345,  67, 150,  37,   9, 217,
#        166,  98, 197, 182, 231, 318,  48, 106,   2, 241, 298, 208, 309,
#        111,  39, 239, 310, 274, 315, 249, 371, 321,  47, 181,  93,  42,
#        128, 358, 312, 393, 313, 154, 170,  83, 260, 365, 341, 146, 285,
#        324, 252, 180, 198, 192, 300, 114, 230,  12, 267, 205,  84, 372,
#        145, 216, 223, 124, 329, 265, 348,   1, 389, 374,  74, 103,   4,
#        251, 363,  56, 317, 307, 261, 244, 129, 157,  78, 380,  40, 379,
#        395, 385,  60, 292, 331, 211, 277, 271,  10, 278, 286, 218,   3,
#        276, 108,  26,  72,  55, 199, 255, 378, 351,  27, 381, 263, 335,
#        334, 201, 246,  52, 147, 136, 209, 302, 125, 346, 353, 169, 338,
#        237, 344,  87, 322, 213, 227, 160, 240, 116,  85, 332, 291, 370,
#        122, 259, 238,  24,  73, 306, 250,  50, 367, 360,  95, 132,  64,
#         38, 288,  29, 194, 356,  96, 119, 337, 369, 364,   7,  34,  18,
#        118,  54, 272,  31, 110,  46, 100, 336, 101, 187, 373, 383, 179,
#        368, 297, 167, 253,  49,  20, 219, 323, 339, 247, 270, 352, 328,
#         80, 202, 228,  99, 392,  36, 158, 144,  28, 325, 186,  33,  23,
#        320,  57, 390, 134,   5, 203,  81, 242, 394, 245, 109, 303, 236,
#        281, 254, 256, 287, 340,  63,  45, 120, 104, 342,  97, 131, 141,
#        304, 284, 280, 290, 112, 391, 343, 264, 258, 388, 176, 117,  17,
#        268,  15, 257, 289, 248, 229,  32, 174, 151,  94,  68, 121, 162,
#        215, 382, 143, 226, 149, 220,  69, 177,  77, 326, 107,  90, 299,
#        127, 142, 135, 140,  19, 185, 183, 178,  16,  14,  11,  25,   8,
#        153, 165, 172, 173, 171, 161, 164, 175, 137, 188, 191, 130, 133,
#        212, 207, 206, 102, 115, 113, 139, 204, 200, 196, 195,  71,  76,
#         70,  89,  82,  66,  41,  44])

# %%
# Assuming imp1 is a numpy array or list of importance scores
x = np.array(range(len(imp2)))

# Sort indices by descending importance
# imp2_ix = np.argsort(imp2)[::-1]

# Create the bar plot with sorted importance
plt.bar(x, imp2)
plt.scatter(x, imp2)


# Set x-ticks to the indices of the sorted bars
plt.show()
